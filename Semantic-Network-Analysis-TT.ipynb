# %% [markdown]
# ## Module Import

# %%
# self defined Modules
from myModules.plot.plotNetwork import Network

# General Modules
import warnings
import pickle

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Load

# %%
DATA_ROOT = './processed-data/'

PERIOD_1 = DATA_ROOT + 'period-1/TT/'
PERIOD_2 = DATA_ROOT + 'period-2/TT/'
PERIOD_3 = DATA_ROOT + 'period-3/TT/'

RESULT_ROOT = './Result/3구간/'

RESULT_1 = RESULT_ROOT + '/1시기/TT/'
RESULT_2 = RESULT_ROOT + '/2시기/TT/'
RESULT_3 = RESULT_ROOT + '/3시기/TT/'

# %%
with open(PERIOD_1+"all.pkl", "rb") as f:
    all_1 = pickle.load(f)
with open(PERIOD_1+"noun.pkl", "rb") as f:
    noun_1 = pickle.load(f)
with open(PERIOD_1+"verb.pkl", "rb") as f:
    verb_1 = pickle.load(f)
with open(PERIOD_1+"adjective.pkl", "rb") as f:
    adjective_1 = pickle.load(f)
with open(PERIOD_1+"adverb.pkl", "rb") as f:
    adverb_1 = pickle.load(f)


with open(PERIOD_2+"all.pkl", "rb") as f:
    all_2 = pickle.load(f)
with open(PERIOD_2+"noun.pkl", "rb") as f:
    noun_2 = pickle.load(f)
with open(PERIOD_2+"verb.pkl", "rb") as f:
    verb_2 = pickle.load(f)
with open(PERIOD_2+"adjective.pkl", "rb") as f:
    adjective_2 = pickle.load(f)
with open(PERIOD_2+"adverb.pkl", "rb") as f:
    adverb_2 = pickle.load(f)

with open(PERIOD_3+"all.pkl", "rb") as f:
    all_3 = pickle.load(f)
with open(PERIOD_3+"noun.pkl", "rb") as f:
    noun_3 = pickle.load(f)
with open(PERIOD_3+"verb.pkl", "rb") as f:
    verb_3 = pickle.load(f)
with open(PERIOD_3+"adjective.pkl", "rb") as f:
    adjective_3 = pickle.load(f)
with open(PERIOD_3+"adverb.pkl", "rb") as f:
    adverb_3 = pickle.load(f)

# %% [markdown]
# ## Network

# %% [markdown]
# ### Period 1

# %%
network = Network(data=noun_1, num_node=30, keywords=['미국', '소련'])
# Out:
#   0%|          | 0/5588 [00:00<?, ?it/s]

# %%
network.plot(centrality='degree')
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
network.plot(centrality='closeness')

# %%
network.plot(centrality='betweenness')

# %%
network.plot(centrality='eigenvector')

# %% [markdown]
# ### Period 2

# %%
network = Network(data=noun_2, num_node=30, keywords=['미국', '소련'])
# Out:
#   0%|          | 0/2950 [00:00<?, ?it/s]

# %%
network.plot(centrality='degree')

# %%
network.plot(centrality='closeness')

# %%
network.plot(centrality='betweenness')

# %%
network.plot(centrality='eigenvector')

# %% [markdown]
# ### Period 3

# %%
network = Network(data=noun_3, num_node=30, keywords=['미국', '소련'])
# Out:
#   0%|          | 0/4022 [00:00<?, ?it/s]

# %%
network.plot(centrality='degree')

# %%
network.plot(centrality='closeness')

# %%
network.plot(centrality='betweenness')

# %%
network.plot(centrality='eigenvector')
